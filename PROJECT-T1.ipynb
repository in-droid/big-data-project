# %%
import pyarrow
import numpy as np
import pandas as pd
import glob
import pyarrow.dataset as ds
import pyarrow.compute as pc

# %%
from pathlib import Path
import re


BASE_DIR = Path("/d/hpc/projects/FRI/bigdata/data/Taxi")

RE = re.compile(r"fhvhv_tripdata[_-]?(\d{4})(?:[_-]?(\d{2}))?", re.IGNORECASE)
min_year, min_month = 2019, 2
def find_parquet_files(base_dir: Path) -> list:
    # files = list(base_dir.rglob("green_tripdata*.parquet"))
    files = list(base_dir.rglob("fhvhv_tripdata*.parquet"))
    selected = []
    for p in files:
        m = RE.search(p.name)
        if not m:
            continue
        year = int(m.group(1))
        month = int(m.group(2)) if m.group(2) else 1  # treat missing month as January
        if (year, month) >= (min_year, min_month):
            selected.append((year, month, str(p)))
    # sort by year, month
    selected.sort(key=lambda x: (x[0], x[1]))
    # return just paths (strings)
    return [p for _, __, p in selected]

# usage
files = find_parquet_files(BASE_DIR)
print(f"Found {len(files)} files (from {min_year}-{min_month} onward).")
for f in files:
    print(f)
# Out:
# Found 72 files (from 2019-2 onward).
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-02.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-03.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-04.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-05.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-06.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-07.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-08.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-09.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-10.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-11.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-12.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-01.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-02.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-03.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-04.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-05.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-06.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-07.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-08.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-09.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-10.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-11.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-12.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-01.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-02.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-03.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-04.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-05.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-06.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-07.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-08.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-09.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-10.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-11.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-12.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-01.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-02.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-03.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-04.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-05.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-06.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-07.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-08.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-09.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-10.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-11.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2022-12.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-01.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-02.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-03.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-04.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-05.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-06.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-07.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-08.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-09.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-10.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-11.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2023-12.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-01.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-02.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-03.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-04.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-05.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-06.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-07.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-08.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-09.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-10.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-11.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-12.parquet
# /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2025-01.parquet

# %%
#!/usr/bin/env python3
"""
PyArrow streaming processor that supports:
 - green/yellow taxi schemas (tpep_ / lpep_ names)
 - hvfhs / fhvhv schemas (pickup_datetime, request_datetime, on_scene_datetime, etc.)
 - keeps airport_fee as string, computes year from canonical pickup_datetime,
   writes parquet partitioned by year=YYYY

Behavior:
 - Lowercases incoming column names
 - Maps a wide set of pickup/dropoff candidate names into a canonical 'pickup_datetime'
   and 'dropoff_datetime' used for parsing and year computation
 - Builds a unified schema (union of expected fields) and emits that schema for outputs,
   filling missing columns with nulls when necessary
"""
import os
import glob
import uuid
import logging
from collections import defaultdict
from typing import List, Dict, Optional

import pyarrow as pa
import pyarrow.compute as pc
import pyarrow.dataset as ds
import pyarrow.parquet as pq

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

subset_files = files

OUTPUT_DIR = "/d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv"

# Union of fields across green/yellow + hvfhs/fhvhv. 
EXPECTED_COLUMNS = [
    # green/yellow taxi typical fields
    'vendorid', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
    'passenger_count', 'trip_distance', 'ratecodeid', 'store_and_fwd_flag',
    'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
    'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
    'total_amount', 'congestion_surcharge', 'airport_fee',
    # hvfhs / fhvhv / fhv-style fields

    'hvfhs_license_num', 'dispatching_base_num', 'originating_base_num',
    'request_datetime', 'on_scene_datetime', 'pickup_datetime', 'dropoff_datetime',
    'trip_miles', 'trip_time', 'base_passenger_fare', 'tolls', 'bcf',
    'sales_tax', 'tips', 'driver_pay',
    'shared_request_flag', 'shared_match_flag', 'access_a_ride_flag',
    'wav_request_flag', 'wav_match_flag'
]


PICKUP_CANDIDATES = [
    'tpep_pickup_datetime', 'lpep_pickup_datetime', 'pickup_datetime',
    'pickup_time', 'pickup_ts', 'pickup', 'request_datetime', 'on_scene_datetime'
]

DROPOFF_CANDIDATES = [
    'tpep_dropoff_datetime', 'lpep_dropoff_datetime', 'dropoff_datetime',
    'dropoff_time', 'dropoff_ts', 'dropoff'
]


TIMESTAMP_STR_FORMATS = [
    "%Y-%m-%d %H:%M:%S",
    "%Y-%m-%d %H:%M:%S.%f",
    "%Y-%m-%dT%H:%M:%S",
    "%Y-%m-%dT%H:%M:%S.%f",
]

BATCH_SIZE = 100_000
ROW_GROUP_ROWS = 2_000_000

# Canonical names used internally
TARGET_PICKUP = 'pickup_datetime'
TARGET_DROPOFF = 'dropoff_datetime'
# --------------------------------------------------------------------------


def discover_files(paths_or_globs: List[str]) -> List[str]:
    files = []
    for p in paths_or_globs:
        if any(ch in p for ch in ["*", "?"]):
            files.extend(sorted(glob.glob(p)))
        else:
            if os.path.isdir(p):
                files.extend(sorted(glob.glob(os.path.join(p, "*.parquet"))))
            elif os.path.isfile(p):
                files.append(p)
            else:
                logger.warning("Path not found (skipping): %s", p)
    if not files:
        raise FileNotFoundError("No parquet files found for the given patterns/paths.")
    return sorted(files)


def read_file_schema_lowered(path: str) -> pa.Schema:
    s = pq.read_schema(path)
    fields = [pa.field(f.name.lower(), f.type, nullable=f.nullable) for f in s]
    return pa.schema(fields)


def _normalize_name_to_canonical(name: str) -> str:
    n = name.lower()
    if n in PICKUP_CANDIDATES or ('pickup' in n and ('date' in n or 'time' in n)):
        return TARGET_PICKUP
    if n in DROPOFF_CANDIDATES or ('dropoff' in n and ('date' in n or 'time' in n)):
        return TARGET_DROPOFF
    return n


def infer_unified_schema(paths: List[str], expected_columns: List[str]) -> pa.Schema:
    observed_types: Dict[str, pa.DataType] = {}
    for p in paths:
        try:
            sch = read_file_schema_lowered(p)
        except Exception as e:
            logger.warning("Could not read schema for %s: %s", p, e)
            continue
        for f in sch:
            canonical = _normalize_name_to_canonical(f.name)
            if canonical not in observed_types:
                observed_types[canonical] = f.type

    # ensure expected columns are present in observed_types (fallback to string)
    for col in expected_columns:
        nc = _normalize_name_to_canonical(col.lower())
        if nc not in observed_types:
            observed_types[nc] = pa.string()

    
    seen = set()
    ordered_expected = []
    for c in expected_columns:
        nc = _normalize_name_to_canonical(c.lower())
        if nc not in seen:
            ordered_expected.append(nc)
            seen.add(nc)
    remaining = [k for k in sorted(observed_types.keys()) if k not in seen]
    final_order = ordered_expected + remaining

    fields = []
    for col in final_order:
        t = observed_types.get(col, pa.string())
        if col == TARGET_PICKUP or col == TARGET_DROPOFF:
            t = pa.timestamp('us')
        if col == 'airport_fee':
            t = pa.string()
        fields.append(pa.field(col, t, nullable=True))
    fields.append(pa.field('year', pa.int32(), nullable=True))
    return pa.schema(fields)


def detect_pickup_name_from_schema(schema: pa.Schema) -> Optional[str]:
    names = {n.lower(): n for n in schema.names}
    for cand in PICKUP_CANDIDATES:
        if cand in names:
            return names[cand]
    for n in names:
        if 'pickup' in n and ('date' in n or 'time' in n):
            return names[n]
    return None


def parse_timestamp_array(arr: pa.Array) -> pa.Array:
    if pa.types.is_timestamp(arr.type):
        return pc.cast(arr, pa.timestamp("us"))
    if pa.types.is_integer(arr.type):
        try:
            maxv = int(pc.max(arr).as_py() or 0)
        except Exception:
            maxv = 0
        if maxv > 10 ** 14:
            return pc.cast(arr, pa.timestamp("us"))
        if maxv > 10 ** 11:
            return pc.multiply(pc.cast(arr, pa.int64()), pa.scalar(1000, pa.int64())).cast(pa.timestamp("us"))
        return pc.multiply(pc.cast(arr, pa.int64()), pa.scalar(1_000_000, pa.int64())).cast(pa.timestamp("us"))
    if pa.types.is_string(arr.type):
        last_err = None
        for fmt in TIMESTAMP_STR_FORMATS:
            try:
                parsed = pc.strptime(arr, format=fmt, unit="us")
                return parsed
            except Exception as e:
                last_err = e
        try:
            return pc.cast(arr, pa.timestamp("us"))
        except Exception:
            raise ValueError(f"Failed to parse timestamp string column. Last error: {last_err}")
    raise TypeError(f"Unsupported timestamp column type: {arr.type}")


def ensure_table_has_expected(table: pa.Table, target_schema: pa.Schema) -> pa.Table:
    existing = {name.lower(): table.column(i) for i, name in enumerate(table.schema.names)}
    rows = table.num_rows

    # map pickup candidates to canonical
    if TARGET_PICKUP not in existing:
        for cand in PICKUP_CANDIDATES:
            if cand in existing:
                existing[TARGET_PICKUP] = existing[cand]
                logger.info(f"Mapped {cand} -> {TARGET_PICKUP}")
                break
        if TARGET_PICKUP not in existing:
            for name in list(existing.keys()):
                if ('pickup' in name) and ('date' in name or 'time' in name):
                    existing[TARGET_PICKUP] = existing[name]
                    logger.info(f"Mapped {name} -> {TARGET_PICKUP} (heuristic)")
                    break

    if TARGET_DROPOFF not in existing:
        for cand in DROPOFF_CANDIDATES:
            if cand in existing:
                existing[TARGET_DROPOFF] = existing[cand]
                logger.info(f"Mapped {cand} -> {TARGET_DROPOFF}")
                break
        if TARGET_DROPOFF not in existing:
            for name in list(existing.keys()):
                if ('dropoff' in name) and ('date' in name or 'time' in name):
                    existing[TARGET_DROPOFF] = existing[name]
                    logger.info(f"Mapped {name} -> {TARGET_DROPOFF} (heuristic)")
                    break

    arrays = []
    names = []
    for f in target_schema:
        if f.name == 'year':
            continue
        if f.name in existing:
            arr = existing[f.name]
            try:
                if not arr.type.equals(f.type):
                    arr = pc.cast(arr, f.type)
            except Exception:
                arr = pa.array([None] * rows, type=f.type)
        else:
            arr = pa.array([None] * rows, type=f.type)
        arrays.append(arr)
        names.append(f.name)
    return pa.Table.from_arrays(arrays, names=names)


def write_partition_table(table: pa.Table, out_dir: str, year: int, row_group_rows: int) -> str:
    part_dir = os.path.join(out_dir, f"year={year}")
    os.makedirs(part_dir, exist_ok=True)
    fname = f"part-{uuid.uuid4().hex}.parquet"
    out_path = os.path.join(part_dir, fname)
    if 'airport_fee' in table.schema.names:
        idx = table.schema.get_field_index('airport_fee')
        if idx >= 0 and not pa.types.is_string(table.column(idx).type):
            try:
                table = table.set_column(idx, 'airport_fee', pc.cast(table.column(idx), pa.string()))
            except Exception:
                table = table.set_column(idx, 'airport_fee',
                                        pa.array([str(x) if x is not None else None for x in table.column(idx)],
                                                 type=pa.string()))

    if 'year' in table.schema.names:
        yidx = table.schema.get_field_index('year')
        ycol = table.column(yidx)
        if not pa.types.is_int32(ycol.type):
            try:
                ycol = pc.cast(ycol, pa.int32())
            except Exception:
                ycol = pa.array([None if v.is_null else int(v.as_py()) for v in ycol], type=pa.int32())
            table = table.set_column(yidx, 'year', ycol)

    new_cols = []
    for i, f in enumerate(table.schema):
        col = table.column(i)
        if pa.types.is_dictionary(col.type):
            vals = [None if v.is_null else v.as_py() for v in col]
            target_type = col.type.value_type
            col = pa.array(vals, type=target_type)
        new_cols.append(col)
    if any(not table.column(i).equals(new_cols[i]) for i in range(len(new_cols))):
        table = pa.Table.from_arrays(new_cols, names=table.schema.names)

    pq.write_table(table, out_path, row_group_size=row_group_rows, use_dictionary=False)

    
    # pq.write_table(table, out_path, row_group_size=row_group_rows)
    logger.info("Wrote %d rows -> %s (year=%s)", table.num_rows, out_path, year)
    return out_path


def process_files_pyarrow(file_paths: List[str], expected_cols: List[str], out_dir: str,
                          batch_size: int = BATCH_SIZE, row_group_rows: int = ROW_GROUP_ROWS):
    files = discover_files(file_paths)
    logger.info("Found %d files", len(files))

    unified_schema = infer_unified_schema(files, expected_cols)
    logger.info("Unified schema prepared with %d fields (incl. year)", len(unified_schema))
    print("Unified schema:")
    print(unified_schema)

    # find pickup candidate name for diagnostics (optional)
    pickup_field_original = None
    for f in files:
        try:
            s = read_file_schema_lowered(f)
            val = detect_pickup_name_from_schema(s)
            if val:
                pickup_field_original = val
                break
        except Exception:
            continue
    if pickup_field_original:
        logger.info("Detected pickup field (lowercased): %s", pickup_field_original)
    else:
        logger.warning("No pickup datetime column found among files (will create null pickup column).")

    buffers = defaultdict(list)
    buffered_rows = defaultdict(int)

    for file in files:
        logger.info("Reading file: %s", file)
        ds_obj = ds.dataset(file, format="parquet")
        scanner = ds_obj.scanner(columns=None, batch_size=batch_size)

        for rb in scanner.to_batches():
            tbl = pa.Table.from_batches([rb])
            tbl = pa.Table.from_arrays([tbl.column(i) for i in range(tbl.num_columns)],
                                       names=[n.lower() for n in tbl.schema.names])

            tbl = ensure_table_has_expected(tbl, unified_schema)

            pickup_idx = tbl.schema.get_field_index(TARGET_PICKUP)
            if pickup_idx >= 0:
                pickup_arr = tbl.column(pickup_idx)
                try:
                    ts = parse_timestamp_array(pickup_arr)
                    tbl = tbl.set_column(pickup_idx, TARGET_PICKUP, ts)
                except Exception as e:
                    logger.exception("Failed to parse pickup timestamp in file=%s : %s", file, e)
                    raise
            else:
                ts = pa.array([None] * tbl.num_rows, type=pa.timestamp('us'))
                tbl = tbl.add_column(tbl.num_columns, TARGET_PICKUP, ts)

            try:
                year_arr = pc.year(tbl.column(tbl.schema.get_field_index(TARGET_PICKUP)))
            except Exception:
                year_arr = pa.array([None] * tbl.num_rows, type=pa.int32())

            if 'year' in tbl.schema.names:
                yidx = tbl.schema.get_field_index('year')
                tbl = tbl.set_column(yidx, 'year', year_arr)
            else:
                tbl = tbl.add_column(tbl.num_columns, 'year', year_arr)

            # coerce airport_fee to string
            if 'airport_fee' in tbl.schema.names:
                af_idx = tbl.schema.get_field_index('airport_fee')
                try:
                    if not pa.types.is_string(tbl.column(af_idx).type):
                        tbl = tbl.set_column(af_idx, 'airport_fee', pc.cast(tbl.column(af_idx), pa.string()))
                except Exception:
                    tbl = tbl.set_column(af_idx, 'airport_fee',
                                         pa.array([str(x) if x is not None else None for x in tbl.column(af_idx)],
                                                  type=pa.string()))

            try:
                yrs = pc.unique(tbl.column(tbl.schema.get_field_index('year'))).to_pylist()
            except Exception:
                yrs = [None]

            for y in yrs:
                if y is None:
                    logger.warning("Found NULL year values - skipping these rows")
                    continue

                mask = pc.equal(tbl.column(tbl.schema.get_field_index('year')), pa.scalar(y, pa.int32()))
                part = tbl.filter(mask)
                if part.num_rows == 0:
                    continue

                # final_cols = []
                # final_names = []
                # for f in unified_schema:
                #     if f.name == 'year':
                #         continue
                #     idx = part.schema.get_field_index(f.name)
                #     if idx >= 0:
                #         final_cols.append(part.column(idx))
                #         final_names.append(f.name)
                #     else:
                #         final_cols.append(pa.array([None] * part.num_rows, type=f.type))
                #         final_names.append(f.name)
                # final_cols.append(part.column(part.schema.get_field_index('year')))
                # final_names.append('year')
                # final_tbl = pa.Table.from_arrays(final_cols, names=final_names)

                final_cols = []
                final_names = []
                # Build arrays cast to the unified schema types
                for f in unified_schema:
                    if f.name == 'year':
                        continue
                    # get array or create null array
                    idx = part.schema.get_field_index(f.name)
                    if idx >= 0:
                        arr = part.column(idx)
                    else:
                        arr = pa.array([None] * part.num_rows, type=f.type)

                    try:
                        if not arr.type.equals(f.type):
                            arr = pc.cast(arr, f.type)
                    except Exception:
                        # fallback: materialize python values and rebuild as desired type
                        vals = [None if v.is_null else v.as_py() for v in arr]
                        arr = pa.array(vals, type=f.type)
                    final_cols.append(arr)
                    final_names.append(f.name)


                yidx = part.schema.get_field_index('year')
                year_arr = part.column(yidx)
                try:
                    if not pa.types.is_int32(year_arr.type):
                        year_arr = pc.cast(year_arr, pa.int32())
                except Exception:
                    vals = [None if v.is_null else int(v.as_py()) for v in year_arr]
                    year_arr = pa.array(vals, type=pa.int32())

                final_cols.append(year_arr)
                final_names.append('year')

                final_tbl = pa.Table.from_arrays(final_cols, names=final_names)

                

                buffers[y].append(final_tbl)
                buffered_rows[y] += final_tbl.num_rows

                if buffered_rows[y] >= row_group_rows:
                    merged = pa.concat_tables(buffers[y], promote=True)
                    write_partition_table(merged, out_dir, y, row_group_rows)
                    buffers[y].clear()
                    buffered_rows[y] = 0

    for y, tbls in buffers.items():
        if not tbls:
            continue
        merged = pa.concat_tables(tbls, promote=True)
        write_partition_table(merged, out_dir, y, row_group_rows)

    logger.info("All done. Output written under: %s", out_dir)


if __name__ == "__main__":
    process_files_pyarrow(subset_files, EXPECTED_COLUMNS, OUTPUT_DIR,
                          batch_size=BATCH_SIZE, row_group_rows=ROW_GROUP_ROWS)
# Out:
# INFO:__main__:Found 72 files
# INFO:__main__:Unified schema prepared with 36 fields (incl. year)
# INFO:__main__:Detected pickup field (lowercased): pickup_datetime
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-02.parquet
# Unified schema:
# vendorid: string
# pickup_datetime: timestamp[us]
# dropoff_datetime: timestamp[us]
# passenger_count: string
# trip_distance: string
# ratecodeid: string
# store_and_fwd_flag: string
# pulocationid: int64
# dolocationid: int64
# payment_type: string
# fare_amount: string
# extra: string
# mta_tax: string
# tip_amount: string
# tolls_amount: string
# improvement_surcharge: string
# total_amount: string
# congestion_surcharge: double
# airport_fee: string
# hvfhs_license_num: string
# dispatching_base_num: string
# originating_base_num: string
# trip_miles: double
# trip_time: int64
# base_passenger_fare: double
# tolls: double
# bcf: double
# sales_tax: double
# tips: double
# driver_pay: double
# shared_request_flag: string
# shared_match_flag: string
# access_a_ride_flag: string
# wav_request_flag: string
# wav_match_flag: null
# year: int32
# /tmp/ipykernel_239667/3513074163.py:476: FutureWarning: promote has been superseded by promote_options='default'.
#   process_files_pyarrow(subset_files, EXPECTED_COLUMNS, OUTPUT_DIR,
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-ab3c6af86d2a42f8a160a6dd9a305f24.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-8dd0744e875e41e28668c09809004eeb.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-64cd93f29bc84e3ba8271d1379287527.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-3ca54e6766a74393bc5ee5a41b7c0cc1.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-8660236a71484e5d8279b969adb4a35f.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-caa67b66402c45759cea1a8456a5c1af.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-3d91c3ae9b8c4b97a4250e29f21c52a9.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1f6e14bb33bb42188a67a8d69822f4cc.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-0ac87ffb50704544ba87db118eb9fec5.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1c333609910c412eabea604b1a88fdcb.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-03.parquet
# INFO:__main__:Wrote 2059102 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-05e5ae59a87a40dfbb7277da8ccb731b.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-84b3ab1e276b44ca9b3705d67ae8db6d.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-36f5c30d6a4c4dd7812d6a60e18c71b9.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-132ae779892e4bd7a6f2832649e7cd1b.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1cc13f35386e4559abfbb22ac46d072c.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-0c91234445044b61ba6f8efa98fc1fc7.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-bb87bb6a4b3d47cbbb18a3a991cfa83b.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-cfad718403be49b8a6ce35306f523273.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-9033172d8467466ca25f3f38c0ed7d47.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-4bec9557c23a47a889270cb5d8acb246.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-d870b45d49ac4dc2a6e4775d393bfbd1.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-04.parquet
# INFO:__main__:Wrote 2064598 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-4f9839b8466c4bb99aa5df569322e6e7.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-74cb4fec60364e8b870f2f7a38233183.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-a29e6b7f4969474fb08f3f049ea28cb7.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-90e54eba79f54251afdb8596820370bf.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-b59ce9f656ea4e80a17b29bcf694d7d7.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-838ef9e8fc83481490642fc56cdabcac.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-8c8f9cad9ea642798d36367049ede3c6.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-be061c39bb184117bd863d9951409a7a.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-f206118b9f7b4475ac4c168fe27e0b7f.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-d9fa713c99274b2d81a489c527a3e707.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-b9eef4e98da9460e8409d56383d46ac7.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-05.parquet
# INFO:__main__:Wrote 2034822 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-256cd37d961b4b38973a38f41d75091d.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-ba59519281eb420daa50a6dc11f79056.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-22da6a1da1414f3b88cb645bd35b8b94.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-2e1e0a5958d745f7889c4dd18ad13c45.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1256e54510e74a16859a28d9b3800b0f.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-a5a09b42c8af4656a200a28c32e4c7d4.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-d58b171bd4a94aba813b2ff0ff485b63.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-c78ebb9a3e774fb383b3d3f26764ad70.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-cd5099decc5546b9b0efce42fa27284f.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-73edfb7f532c4207a7057f7e2bc852e6.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-f1cc407e54ad46f5854c9be824f0646f.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-06.parquet
# INFO:__main__:Wrote 2029247 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-d9ecb398af2144f598644f046f8c8c13.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-587df94a16304fc1b2a13dca9d7e2d52.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-3be7d2ceabec41a997e4c08d650575d3.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-2a015bc90a20417c9c162f6185f6cd8e.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-2454e81645cd4abbb93994a545b062a7.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-d9067ed110904fa69973bd4a3037ea77.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-00075edf55eb4bf692907585852af139.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-3e84bd5f943e48e2995bd9346d49df05.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1dee73a5b7b44597bedb91c57a3ac40f.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-c5610e2890274a2e8a82a78339d89d26.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-eda6d51dd4824e95a246d2f1cda933e8.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-07.parquet
# INFO:__main__:Wrote 2001990 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-78c6edcd475f43dab2a054ad0de75e48.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-77dcdb928a9c4758961f76d2863c4692.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-4b335926298146bc9e0b37377c3cb1db.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-3c7e3ab0110b4a34a58cfe65672f2a2a.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-35da51d7350d445db169d1b3fe5529ac.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-322268c792f8448eb677220111898349.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-7eb757a6aa8b44dd9ecdfe19542ced96.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-ece8dda7d9f04fedb9a6b8d3b3296684.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-8c3b2f20413644f4965047e47cc58bfa.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-98ff4615fe0744668ae0fbbf10710db3.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-08.parquet
# INFO:__main__:Wrote 2003312 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-0831f1641c4e4c89951abb9510ad9fe8.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-470e619359954586ac128e2b2de49549.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-24473597dc1d4fcab64844aed5fd25c1.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-9cbb512b31eb41179716f8ac14aa9058.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-396873b553d642298ea5f8fb4242b8cf.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-0ad16aed62464922953e829eb186abc3.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-702bd39e39bb49acb54c38b7b032cdd3.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-4bdd55f1d8d64187971b7f0b0956b289.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-cd2ff61cd0224ed18c471697f32bc178.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-a71e7acf709f4b5b8e801bb982676871.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-09.parquet
# INFO:__main__:Wrote 2026113 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-9351ac2aab6146028451ee4054d1ee9c.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-fe05ee27ad2846218dcfe73078a1347f.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1f644215e9db427eb6647ef86ccf8266.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-f0271c4eee5248708e2c5d2a6f4ec1f9.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-ac71531fd29a48eaa40ffc8542aaf325.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-0621e75d4dbc47349b30115bd8164ffe.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-2b56aa99be5045ac9aeb79f1c08ee52e.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-b78d413987e34dfb9ecc6871474e0391.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-335c8e9360a2483e95d019d5e7b6d36f.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1e441a560ce04bc496e4272154d138bf.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-10.parquet
# INFO:__main__:Wrote 2069321 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-c2687586b3e44d59bd26ef33d8e4a2f5.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-06f810c537f44715b4fc41aad16ad4d6.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-c64be62d8f4c433c914eb5f74a90fab9.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-38b48f2b6be2421b97546559402f6f03.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-71715b3caab84aa7aafdc8fa52028477.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-851e910098304f10b6bfd2ba79b101a9.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-e55e4ecf19b64df9accdb9efaa749e60.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1b7c53e9c9024052a5e0da856db2a52e.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-a1adf754012e46518a342212e9b432de.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-a406c2b25dcc4061bc35f5df5fdb3e01.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-3a6d983a2a8841839f0ac882d78afe2a.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-11.parquet
# INFO:__main__:Wrote 2062290 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-5569336917d647e987ed6aadbd2d2f46.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-7e4932e283bf45468dbe86561820530e.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-94e9451857974875a62a456e33706a4c.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-dbe008e13b1d4cd9abeca10dc96e3319.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-aef83702c5344610b58c409aa944d901.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-796045652fcf4ae28944c5e2fb1f566c.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-f72108aa75d14d6193510e4c712ffc00.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-61145cc3f4e54042a307fd039d3a7f9b.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-a4cd417de83f4ec3941cdaf3f64ebcac.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-26906ec0196e40fab5d46bd763e937ab.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-bbd2202af0d148ada04bb103b7ee35f1.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-12.parquet
# INFO:__main__:Wrote 2035568 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-55276979824244bdac3fe81b1340de70.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-ca21d1a3a1fd4673a4a79a4b3f0692ab.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-0590d0a16dc74b15879bf7fa03f175ae.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-1fbf8381a41d4cbf802947f4a8ef220d.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-74ba3a02cfd141748441be1bb37d2bda.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-b696bde3e4b34d5082fd8ba8863fdc60.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-da5f535987094ae98948b634e165f2e8.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-4e458d1ba33845918d1bfb0bb31776db.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-28861f5176964aa8b8ce63b0ec522dd7.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-d25d805fc3b34ad2bc63933446da31d9.parquet (year=2019)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-3983bed0fd014d689951ea10683f2e9e.parquet (year=2019)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-01.parquet
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-2ac9cfc17773408da3421bf364e9c78c.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-d6f21320449647a3acd4be5259f66005.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-995fc012df6543e29f908380aebed874.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-45f9c7ead0ea421a82751001e7a19dff.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-28e6101f0d5b40a887b3aad4ce6c7981.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-8e630d63c78547ec95c7b1414c92e01d.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-9858d6249c37464bb5a051551390d7b8.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-1a475e0a0d914ab7ab80cd0247dd9189.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-773ce3e0972a458fb577314386b9ec5b.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-b2ea24a9b22f4c7987e5d6a477903df6.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-02.parquet
# INFO:__main__:Wrote 2069368 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-9d0c7bf656e34ee498445e439691b779.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-8ad83da137f947298f6ae05e8a678446.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-380763e77e2541299514737e29b7c658.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-fe38e5d5b4f74a7985349e93fe1931ae.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-2fb5d4c9489b42d9b3ef32bf473fe982.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-28f40c6dcf4342519df126e1f0d7b1ca.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-13d4d61db95d40618c8fa4c7e21e7b92.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-bf67eed531684c46a26ca8b964459239.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-c3b7d65fc54a409581da5fe255b18175.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-67b21b26b7ec4ad3b181d84c547937a2.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-34db207a9e8a4a57ba9b72ebfb5df0fd.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-03.parquet
# INFO:__main__:Wrote 2025100 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-4d196344cbad4f1b9d2064d88e201a50.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-741511db1f8d46a1b50925d5ee7d1cf8.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-d45383fbbdcf4b3d9d0fb378b3dfb3f3.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-7c46f5d42e82475ca53a6b85cc4641c5.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-53685fb9ea574fd292e8c3e41f5983b7.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-682e86a92b5443a8ba9f02833f4e6a46.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-04.parquet
# INFO:__main__:Wrote 2092928 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-371a2fe6eb7d4d0b97545f63e5bb4ed9.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-efb21bba6e2a43248d36619fc541ebb5.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-05.parquet
# INFO:__main__:Wrote 2012909 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-d24a20fcdca441bf958593523ecabe0c.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-7ad75176198449c79a645bddb538e548.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-8315baed0a044b4998a7d1037e061ec4.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-06.parquet
# INFO:__main__:Wrote 2089999 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-ba441a5a574b4080ac34e8d7884ef357.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-53a1b8e372054253b30e48a23ccacb1c.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-2c0882574a394e36977cde9a734b3292.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-29b28586f801426386b3ece55377d882.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-07.parquet
# INFO:__main__:Wrote 2055193 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-b45dc6db59b34ff780eb4acd5329933b.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-f458bcef33eb4db582c53fdc2cb52f3a.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-081b3178a4ab400ba7adb002e29895fa.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-f239ff7d95e5453fa597538fb310046e.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-54faec3d67594cacb778a00d1cc9ee26.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-08.parquet
# INFO:__main__:Wrote 2058454 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-b9c94e32559b4abe901264c8ac4e8ade.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-e6c1b1c6f6234fd79056afcfa0bdc971.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-09054dd5832f4e6ebb0ba9358a696c6c.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-12ceeb08e3b34035af2bd3b31a1331f4.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-0f887a35d171420a847fb58948a57028.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-fd9e1fbf392c42fc98de52997fcf5d1b.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-09.parquet
# INFO:__main__:Wrote 2096852 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-49a6cca6ce5f426495ec44fc2013698d.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-6c8880f44c13421c8d86f71983389544.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-fe7564d3bfa04d12aaf5e2ae83e9d157.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-1d4eaba7ae9c477d8acc080f70970dde.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-0ec427fcaa1a4142a88d9d9658bb0602.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-6d15db90ded54d43a3623fcb07aa9044.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-10.parquet
# INFO:__main__:Wrote 2006669 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-95daf501c7054344a998ad1db49c98b2.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-e0c5148c6f554fc69b2c9690aa0c5f23.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-353254d846a440acae6f8782017b6d6c.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-0777f4619c1c4b67b8edbd69712e7c11.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-380e74f3f3b54d2c8eee796487ea7e88.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-716e2f75567040f091b8cc839487f840.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-11.parquet
# INFO:__main__:Wrote 2068411 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-857b0c4fe4994bbb94637e797ddb4fb2.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-246d2554ea1843778be53c649de2e9be.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-d1a02cc25bbe4fe790ed35715eceb83d.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-f9264205d0dc43e6893da557ebd6706a.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-7883df57fcc04af1a6acb97e006ae210.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-ea2c20ce38c74b2d8cd5f240433cae7e.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2020-12.parquet
# INFO:__main__:Wrote 2096865 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-3e934a38064744f8be0204bcb326cd50.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-21931148e8584033ad158acda9827a71.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-8257b823583d4e86a4ae6fc01dec04f8.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-f85e4d4039c74b129d8caf230cbc02b2.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-b4473ea723e34eb79afb4cd983fc74d6.parquet (year=2020)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-ab742c1b93374e2bba014bafa827b4b5.parquet (year=2020)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-01.parquet
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-698e9edc8c7c427ba74e84e9bb761fd4.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-b9662236234c46158a2b5bb52738128d.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-561e471046d74fc1ba74efd339a7afc8.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-d583134f2bb74879b83f2233df1669e7.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-33f34cf25a2242d7a7c56a76a0776739.parquet (year=2021)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-02.parquet
# INFO:__main__:Wrote 2008468 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-85b95181b2864cec9b30b41236b601e5.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-bd1949a374bc42cbac4219a7f422c6b9.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-403cb8f85c224d4686ea23e7813ef7cf.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-24dbfa0914184c53a717a65350061a7b.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-1cd0a491896f4cf6bc140ccd303c3ecc.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-2c4f5a543f0149a9a54422c3a243399c.parquet (year=2021)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-03.parquet
# INFO:__main__:Wrote 2013942 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-5a890c86f6414424896a46e48ffe4c22.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-6fbeb41f24c34b32b44db8511c6c43e2.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-9f68a6c0692742f8878b63502399e671.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-cbfcd22c66974d04a17ba0d37029fd2b.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-bb255793912841a398e6b8e4a56c186f.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-6a9bdbd1b6fe4a28b19c9c0bc976a787.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-d745be56e18044bd94b6edc454a1ab8a.parquet (year=2021)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-04.parquet
# INFO:__main__:Wrote 2027393 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-9ad5ce558c4f4eb983d2b094ec3f7eed.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-37c46240363542159dc53607c2252c9e.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-4fb43fda30294ff9b1f502ccfd728828.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-1674ee93fd634be79e4b6705b04e2eea.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-2092108b226f40cd803b126dfc671117.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-33496da263a44862a2676b1e17d451bc.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-823b6ea17098496994224b780f14d052.parquet (year=2021)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-05.parquet
# INFO:__main__:Wrote 2011371 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-476f454bd0fa43dc89035ca5f2aaa0ab.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-f518822d29fc4472807c889e6b6689e4.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-207034d095ba48189b62bc7449b46dff.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-154a7ad92faf45b0823e20d391d088de.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-a7af165c99a64b00ab0f9934488de1f4.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-bf8d9e9cdf2143f8b6d4a7c21daa4950.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-d0e9d1fc28d5417db24be31785cd44ae.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-a93844eff733410197fa15c46292e074.parquet (year=2021)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-06.parquet
# INFO:__main__:Wrote 2019171 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-bd76ac386be14cdfaa82a2b7a29a7afd.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-fc75bf579a8442629b84af8b4e4a297a.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-dcab7b3bd14c4cfe8f057aaab7887b79.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-dfcc397d53dd49ffbcdf3216593481bd.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-4d87c963443b4539b93f6240fe8e09cb.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-d36bcccf86fd485180b776fa2832cdd5.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-10348e9ca59349c0a261d3e56508e157.parquet (year=2021)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-07.parquet
# INFO:__main__:Wrote 2061892 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-89ea43d199124f2f87b37038232ea00c.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-10e6e50efc3141fdb639368f86f0bf1d.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-f7723885801a42beb8e1db9ecb3371b2.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-4bdd1536a441444b8159b757509181ce.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-8e1cb16496314006b88c121b8a25af9e.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-b81c1f08ab66441d80aacc0f27829d91.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-97ca5c90a8fb47e4b375af308a80e1a4.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-1ba2802b14c04111bdbb2324e5cea0ad.parquet (year=2021)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-08.parquet
# INFO:__main__:Wrote 2027174 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-fbc7b4c2d17e4a1c80a7edf46e8adf5c.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-6227aa20886045b787dd9ceefba262f7.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-c93f2e9fe658472f97d66e724aa9f3ab.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-12402c68db8a427fa593d07a7f0da067.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-707c433a04db4d29a07b2cff65ebb9ba.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-ae6b21ea70254a49ab9d7bbd0abb1262.parquet (year=2021)
# INFO:__main__:Wrote 2000000 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-dfd68b5e1f10400b9c83ba437eefd40e.parquet (year=2021)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2021-09.parquet
# ...
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-b52b66ce0e9048b6976a619b71fd2185.parquet (year=2024)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-06.parquet
# INFO:__main__:Wrote 2030170 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-cd4c5cc4e82d4ea8ad1902b96b7fbdb6.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-7702afcace10481ba824156cb5d9d55b.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-249abe5f45684819b3cd04b1d14bdccf.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-1fe903c06a5e40d694b7e524cbcd6427.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-1e1cd3f45e394968b4f3a78d60f32392.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-9081989cbd1c46b2b7bc0677e63a0fc6.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-57256c633fe34237990ba0ac631d4495.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-7376eb8bf68e489e9f755565d3c4fc0e.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-5edfee2bc67a4ba48ce4af91bf4dfb82.parquet (year=2024)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-07.parquet
# INFO:__main__:Wrote 2097434 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-744eb1308af34481b1606ebdd1f65eb0.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-af2e8f1d51c546fea5a40e48ffe72c11.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-42f846c7c10845e481f119ef6db3f97b.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-cdb3d257922b4b53bd38b5903d039af5.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-5b09a8e6cebb4f408d34795ecbd9da7b.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-6619599af50b4778a8914bb1ea90daf5.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-614cbf63ac4444979600d4b519f69c02.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-6f929f055c2f4fd3b2b9336cc68275a9.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-8418f52bcc3541578d95a7af294dda42.parquet (year=2024)
# INFO:__main__:Wrote 2005718 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-266ede1c547f41dcab51a6008f9428cc.parquet (year=2024)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-08.parquet
# INFO:__main__:Wrote 2048576 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-5f7d0df468094c719345e200f2cb7004.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-291f4d7353764c9282a6648f0572e94a.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-9ab6c9e682c44836b3e482faff4a4f6d.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-25e84b2f1df14c63b46bad36ed69fd8d.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-b1bd43106e124814a70a131e522b4336.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-82ec622cb8e44caaa27a028969707f30.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-39172a3131bb4da7b7241050065b3729.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-7359363f11f249f4a075bbd1ac402476.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-283e8a740371487986a4b41ec6cf00d0.parquet (year=2024)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-09.parquet
# INFO:__main__:Wrote 2051176 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-cb771f31cf3d4f2992da65c985b2f137.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-cf86b5ce86584991bd2e3d51420d6699.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-36baf0056d7d4af2b8612b84013aea40.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-06b71ecd13b3481ea37e804ae1328613.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-d1903934bc2a4196946d7068378921ae.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-0911ad1ecc29446d99cda91bac81368f.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-22fba56f549e46f7970678e63b75f28c.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-d1957b100d8c46cea016039fcd81aacf.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-dbec9bc184784b9f8b7676364e880a5d.parquet (year=2024)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-10.parquet
# INFO:__main__:Wrote 2032572 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-3688edbbbf38404cb300ea23bfb5718a.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-53cda2fb32664bba8cd1234edd0a28cb.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-9ee9499774eb467eaccbb9178d15853a.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-ecbb81b1b8b54ac29c2ec4b06eecd1f7.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-ecd5c7b0077649d5b5ae304f9642906a.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-2c7e7a2944734a2ab9554ab0f1e3e0f7.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-049f2c3fca7543beaa6e07cd7d697609.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-40ee5eb0acdb4b24a11a32e5c2c6a94c.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-9ee437fa632749b0a5d8cd774ce78655.parquet (year=2024)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-11.parquet
# INFO:__main__:Wrote 2002490 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-69cd1a801e3442d198cad5d95f00b83d.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-7e61cbacf16e4affb06c9ea2f288a92b.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-7b5c9cc5e167450bb39e859c1309d30e.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-ef08b416949a4108ba92791c47cd55f7.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-725e8972e83d4e42b1519b9afb40c971.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-0aa67fd0400f4436802ef46fd71ce1d8.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-39110b1211b14002ba11ab8a1f92e10d.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-9d8b79bae07c427bb80a0e318a45eca4.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-5f71fa6c015f4718a7648aa269973ed6.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-8a9777baa77c4c30a72dff02130895b6.parquet (year=2024)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2024-12.parquet
# INFO:__main__:Wrote 2013165 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-e8a56401536d4ffdbcc2788e84858e58.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-962491034157489d82d84c01cd5f40b2.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-c486016068704fb99fc04fa5f48c9c1c.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-5f70c857c0b841ae915d430907b815a5.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-89927b28f2be4d85afa64c2321c3493f.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-91137b125edf4a74b16495324bd37164.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-074f8dd5ad3c420697abcd98054545aa.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-70467251c91340698fe3a8b1bfbdaf6b.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-2bab2030c58c4284b6652a97a062140f.parquet (year=2024)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-ce7119fc08434c25b5384f0a332af847.parquet (year=2024)
# INFO:__main__:Reading file: /d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2025-01.parquet
# INFO:__main__:Wrote 2048576 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-58c6860eb2514a9c963262b8036b78ec.parquet (year=2025)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-ab8b9d18356941e2ba34f0c9fd0c8a60.parquet (year=2025)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-e78506655c3946f2be893bd7c71dc19d.parquet (year=2025)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-2798d2cdcbb44b30b2c24eb9e2957e78.parquet (year=2025)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-aadc60af1bc844e3a11f03e8fedb4536.parquet (year=2025)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-bfdd83702bc040da8dba0a1e8eda0206.parquet (year=2025)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-ab60f7e552a34794a048775f8d4d8337.parquet (year=2025)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-2963d8ac276c4e1bb9d721ccdfec655b.parquet (year=2025)
# INFO:__main__:Wrote 2097152 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-a96a3271d15e4333af2a8a28bfc9a997.parquet (year=2025)
# INFO:__main__:Wrote 243901 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2019/part-c86a0e47cb1547d78fa86f42df052b40.parquet (year=2019)
# INFO:__main__:Wrote 637123 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2020/part-eb63f9ffe7fc4eb0848e80af334ad91c.parquet (year=2020)
# INFO:__main__:Wrote 154495 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2021/part-2c8844725e9041c7ad9a20f8c8ffa96f.parquet (year=2021)
# INFO:__main__:Wrote 1765847 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2022/part-bc50002f62354e1da36d80addc70e4b3.parquet (year=2022)
# INFO:__main__:Wrote 1890505 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2023/part-90c1ec73d9d94ae5b6ce8ef450a98e29.parquet (year=2023)
# INFO:__main__:Wrote 1194483 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2024/part-d846249dd257482cbdc3421d1f11496c.parquet (year=2024)
# INFO:__main__:Wrote 1579874 rows -> /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv/year=2025/part-26d2916477354e638cb808df3bae732f.parquet (year=2025)
# INFO:__main__:All done. Output written under: /d/hpc/projects/FRI/bigdata/students/in7357/optimized_parquet_pyarrow_fhvhv

# %%
import pyarrow.parquet as pq


p = "/d/hpc/projects/FRI/bigdata/data/Taxi/fhvhv_tripdata_2019-11.parquet"  # pick a file
print("Parquet schema (original):")
print(pq.read_schema(p))

tbl = pq.read_table(p, columns=None, use_pandas_metadata=False)
print("Lowercased columns:")
n_rows = tbl.num_rows
print(f"Rows: {n_rows}")
print([n.lower() for n in tbl.schema.names])

for cand in PICKUP_CANDIDATES + ['lpep_pickup_datetime','pickup_datetime']:
    if cand in [n.lower() for n in tbl.schema.names]:
        arr = tbl.column([n.lower() for n in tbl.schema.names].index(cand))
        print(f"Found candidate column: {cand} — type: {arr.type}")
        # print first 5 non-null values (safe)
        nonnulls = [x for x in arr.to_pylist() if x is not None][:5]
        print(" first 5 non-null values:", nonnulls)
        print(" first 5 non-null values:", nonnulls)

# %%
import dask.dataframe as dd

# %%
df_test =
